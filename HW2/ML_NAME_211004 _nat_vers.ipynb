# %% [markdown]
# <div class="alert alert-block alert-info" >
#     <h1>Machine Learning: Assignment 2</h1>
#     <h2>This is a two week assignment</h2>
#     <h3>General Information:</h3>
#     <p>Feel free to add cells if required.<br> Feel free to write your own function block to reduce the redundancy.<br> Answers belong into the corresponding cells (below the question). <br><br> If you encounter empty cells underneath the answer that can not be edited, please ignore them, they are for testing purposes.<br><br>When editing an assignment there can be the case that there are variables in the kernel. To make sure your assignment works, please restart the kernel and run all cells before submitting (e.g. via <i>Kernel -> Restart & Run All</i>). We don't consider that respective solution if you make this mistake (no excuse).</p>
#     <br><br><b> Plot should have axis labels, grid, legend, title, atleast size 10X10 .Also give proper comments, function name, variable names to your coding, if you didn't follow the instructions there will be a reduction in the points.</b><br><br>
#      <br><br><b> Write sudo-code if you didn't get output or left out of time so that you will be awarded with atmost 50% of marks for that particular session.</b><br><br>
#     <h3>Submission:</h3>
#     <p>Use the following naming convention for your submissions: LA_FirstnameLastname_dateOfLecture, e.g LA_JohnDoe_YYMMDD
#      <br><br>Please submit your notebook via LEA. The assignment is due on <b>$16^{th}$ October, Saturday at 18:00.</b> </p>
#     <h3>Group Work:</h3>
#     <p>You are allowed to work in groups of up to two people. Please enter the UID (your username here) of each member of the group into the next cell. We apply plagiarism checking, so do not submit solutions from other people except your team members. If an assignment has a copied solution, the task will be graded with 0 points for all people with the same solution.</p>
#     <p><b>YOU SHOULD ONLY SUBMIT EXACTLY ONE PER GROUP</b></p>
#     <h3>Questions about the Assignment:</h3>
#     <p>If you have questions about the assignment please post them in the LEA forum before the deadline. Don't wait until the last day to post questions.</p></div>

# %%
'''
Group Work:
Enter the UID (i.e. student2s) of each team member into the variables. 
If you work alone please leave the second variable empty, or extend the list if necessary.
'''
member1 = 'nquiro2s'
member2 = 'slatou2s'

# %% [markdown]
# # Build a spam classifier using Naive Bayes[100 points]

# %%
#Headers
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn
#Include your other headers here
import re
import nltk
from nltk.corpus import stopwords
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics import f1_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report
#nltk.download()

# %% [markdown]
# ## Step 1:- Load your data[10 points]
# #### There are three datasets for training: TrainDataset1.csv, TrainDataset2.csv and TrainDataset3.txt. Each dataset contains short messages with the labels (ham or spam). Load the dataset using pandas.

# %%
#Load your dataset in this cell
def loadData(nameFile):
    if '.csv' in nameFile:
        if 'Train' in nameFile:
            file = pd.read_csv(nameFile)
            file.columns=['type','text']
            return file
        else:
            file = pd.read_csv(nameFile)
            file.columns=['text']
            return file
    else:
        test = []
        for line in open(nameFile,'r').readlines():
            columns = []
            for col in line.split('	'):
                columns.append(col)
            test.append(columns)
        return pd.DataFrame(test,columns=['type','text'])

# %% [markdown]
# ## Step 2:- Preprocess the data[20 points]
# #### Analyse the data, for this you will need to process the text, namely remove punctuation and stopwords, and then create a list of clean text words (Research how to do this [Hint:- see how the texts are pre-processed in Natural Language Processing]) use any libraries that you feel comfortable. Now Combine them into one big data set for the training.

# %%
#Pre-process the data
def preProcessing(dataset_brut):
    stop_words = set(stopwords.words('english'))
    for i,row in dataset_brut.iterrows():
        dataset_brut['text'][i] = re.sub('[,;.!?*@#$€£+-/]', '', dataset_brut['text'][i])
        filtered_sentence = []
        for word in dataset_brut['text'][i].split(' '):
            if word not in stop_words:
                filtered_sentence.append(word.lower())
        dataset_brut['text'][i] =  filtered_sentence 
    return dataset_brut

# %% [markdown]
# ## Step 3:- Visualise the data[20 points]
# #### Try to visualize and analyse the data such as before and after pre processing, number of ham/spam etc. Analyse as many verticals you can, feel free to use graphical libraries like seaborn.

# %%
#Visualise the data
brut = loadData('TrainDataset1.csv')
print('Data befor pre-processing.')
print(brut)
net = preProcessing(brut)
print('Data after pre-processing.')
print(net)
#your code here
print('Number of Ham & Spam')
print(net['type'].value_counts())
ham, spam = net['type'].value_counts()
plt.bar('spam',spam)
plt.bar('ham',ham)
plt.title('Number of ham and spam')

def create_vocabulary(text):
    vocabulary = []
    for sms in text:
        for word in sms:
            vocabulary.append(word)
    return vocabulary
ham_vec = {}
spam_vec = {}

def create_dic(text):
    for i, line in text.iterrows():
        if line['type'] == 'spam':
            for word in line['text']:
                if word not in spam_vec:
                    spam_vec[word] = 1
                else:
                    spam_vec[word] += 1
        if line['type'] == 'ham':
            for word in line['text']:
                if word not in ham_vec:
                    ham_vec[word] = 1
                else:
                    ham_vec[word] += 1
    return ham_vec, spam_vec

vocabulary = create_vocabulary(net['text'])
ham_vec, spam_vec = create_dic(net)

print()
print('TOP 20 MOST COMMON WORDS')
print('Word     Frecuency')
pd.Series(' '.join(vocabulary).lower().split()).value_counts()[:20]
# Out:
# Data befor pre-processing.
#       type                                               text
# 0      ham  Hope you are having a good week. Just checking in
# 1      ham                            K..give back my thanks.
# 2      ham        Am also doing in cbe only. But have to pay.
# 3     spam  complimentary 4 STAR Ibiza Holiday or £10,000 ...
# 4     spam  okmail: Dear Dave this is your final notice to...
# ...    ...                                                ...
# 5554   ham  You are a great role model. You are giving so ...
# 5555   ham  Awesome, I remember the last time we got someb...
# 5556  spam  If you don't, your prize will go to another cu...
# 5557  spam  SMS. ac JSco: Energy is high, but u may not kn...
# 5558   ham                    Shall call now dear having food
#
# [5559 rows x 2 columns]
# Data after pre-processing.
#       type                                               text
# 0      ham                 [hope, good, week, just, checking]
# 1      ham                              [kgive, back, thanks]
# 2      ham                          [am, also, cbe, but, pay]
# 3     spam  [complimentary, 4, star, ibiza, holiday, 10000...
# 4     spam  [okmail:, dear, dave, final, notice, collect, ...
# ...    ...                                                ...
# 5554   ham  [you, great, role, model, you, giving, much, r...
# 5555   ham  [awesome, i, remember, last, time, got, somebo...
# 5556  spam  [if, prize, go, another, customer, t&c, wwwtcb...
# 5557  spam  [sms, ac, jsco:, energy, high, u, may, know, 2...
# 5558   ham                          [shall, call, dear, food]
#
# [5559 rows x 2 columns]
# Number of Ham & Spam
# ham     4812
# spam     747
# Name: type, dtype: int64
#
# TOP 20 MOST COMMON WORDS
# Word     Frecuency
# i       1478
# u       1294
# call     576
# 2        474
# ur       389
# get      383
# i'm      379
# you      314
# 4        292
# go       282
# free     275
# ok       272
# know     257
# like     244
# got      239
# good     236
# come     228
# time     211
# day      201
# love     194
# dtype: int64

# %% [markdown]
# ## Step 4:- Build, train and validate the classifer, [20 points]
#
# ### Training on supervised data (labelled data)
#
# #### Use the data in order to build your own Naive Bayes classifier (You can either use existing Naive Bayes from sklearn or build your own). Build the classifier, train it and then validate. Provide your result in confusion matrix (use heatmap from seaborn) along with the classification report from sklearn. Validation accuracy should be around 99%.

# %%
def classify(message, ham_vec, spam_vec):
    
    p_spam_given_message = 1
    p_ham_given_message = 1
    
    for word in message:
        if word not in spam_vec:
            p_spam_given_message *= 1
        else:
            p_spam_given_message *= spam_vec[word]
            
        if word not in ham_vec: 
            p_ham_given_message *= 1
        else:
            p_ham_given_message *= ham_vec[word]
            
    if p_ham_given_message > p_spam_given_message:
        res = 'Ham'
    elif p_ham_given_message < p_spam_given_message:
        res = 'Spam'
    else:
        res = 'I dont know'
        #print(message, ' I need human help')
    return res
        
def Training_on_supervised_data(net): 
    
    net['type'] = net['type'].apply(lambda x: 1 if x == 'spam' else 0)
    x_train, x_test, y_train, y_test = train_test_split(net['text'], net['type'], test_size = 0.3, random_state = 0)   

    print('Rows in test set: ' + str(x_test.shape))
    print('Rows in train set: ' + str(x_train.shape))

    document_train = [''.join(str(item)) for item in x_train]
    document_test = [''.join(str(item)) for item in x_test]

    vectorizer = CountVectorizer()
    features_train_transformed = vectorizer.fit_transform(document_train) #gives tf idf vector for x_train
    features_test_transformed  = vectorizer.transform(document_test) #gives tf idf vector for x_test
    classifier = MultinomialNB()
    classifier.fit(features_train_transformed, y_train)
    print("classifier accuracy {:.1f}%".format(classifier.score(features_test_transformed, y_test) * 100))

    predicted = classifier.predict(features_test_transformed)
    actual = y_test.tolist()
    results = confusion_matrix(actual, predicted)
    print('Confusion Matrix :')
    print(results)
    print ('Accuracy Score :',accuracy_score(actual, predicted))
    print ('Report : ')
    print (classification_report(actual, predicted) )
    score_2 = f1_score(actual, predicted, average = 'binary')
    print('F-Measure: %.3f' % score_2)
    sns.heatmap(results, annot=True)
    
Training_on_supervised_data(net)
ham_vec, spam_vec = create_dic(net)
# Out:
# Rows in test set: (1668,)
# Rows in train set: (3891,)
# classifier accuracy 98.9%
# Confusion Matrix :
# [[1459    5]
#  [  14  190]]
# Accuracy Score : 0.9886091127098321
# Report :
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99      1464
#            1       0.97      0.93      0.95       204
#
#     accuracy                           0.99      1668
#    macro avg       0.98      0.96      0.97      1668
# weighted avg       0.99      0.99      0.99      1668
#
# F-Measure: 0.952

# %% [markdown]
# ## Step 5:- Test the classifier[10 points]
#
# ### Supervised classification[5 points]
#
# #### Test your Classifier using  the SMSSpamCollection.txt dataset provide a heatmap and classification report. Test accuracy should be around 99%.

# %%
# Test the classifier

brut = loadData('SMSSpamCollection.txt')
net = preProcessing(brut)

print('Number of Ham & Spam')
print(net['type'].value_counts())
ham, spam = net['type'].value_counts()

Training_on_supervised_data(net)
# Out:
# Number of Ham & Spam
# ham     4827
# spam     747
# Name: type, dtype: int64
# Rows in test set: (1673,)
# Rows in train set: (3901,)
# classifier accuracy 98.3%
# Confusion Matrix :
# [[1425    6]
#  [  22  220]]
# Accuracy Score : 0.9832635983263598
# Report :
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      1431
#            1       0.97      0.91      0.94       242
#
#     accuracy                           0.98      1673
#    macro avg       0.98      0.95      0.97      1673
# weighted avg       0.98      0.98      0.98      1673
#
# F-Measure: 0.940

# %% [markdown]
# ### Unsupervised classification[5 points]
#
# #### Test your Classifier using  the TestDataset.csv dataset. This dataset is not labelled so kindly predict the labels and visualise it[5 points].

# %%
brut = loadData('TestDataset.csv')
net_new = preProcessing(brut)
vec = []
print(net_new)
for i, row in net_new.iterrows():
    vec.append(row)
    vec.append(classify(row['text'], ham_vec, spam_vec))
print(vec)
# Out:
#                                                    text
# 0         [prabhai'm, sorydarealyfrm, heart, i'm, sory]
# 1                                      [jus, chillaxin]
# 2                            [ok, prob, take, ur, time]
# 3     [congrats, 2, mobile, 3g, videophones, r, call...
# 4           [thankyou, much, call, i, appreciate, care]
# ...                                                 ...
# 1111  [god, created, gap, btwn, ur, fingers, dat, su...
# 1112  [i'm, working, technical, support, :)voice, pr...
# 1113                         [i, told, number, gautham]
# 1114                              [well, big, surprise]
# 1115                                                [u]
#
# [1116 rows x 1 columns]
# [text    [prabhai'm, sorydarealyfrm, heart, i'm, sory]
# Name: 0, dtype: object, 'Ham', text    [jus, chillaxin]
# Name: 1, dtype: object, 'Ham', text    [ok, prob, take, ur, time]
# Name: 2, dtype: object, 'Ham', text    [congrats, 2, mobile, 3g, videophones, r, call...
# Name: 3, dtype: object, 'Ham', text    [thankyou, much, call, i, appreciate, care]
# Name: 4, dtype: object, 'Ham', text    [good, morning, dear, have, great, &amp, succe...
# Name: 5, dtype: object, 'Ham', text    [desires, u, going, doctor, 4, liver, and, get...
# Name: 6, dtype: object, 'Ham', text    [how, stupid, say, challenge, godyou, dont, th...
# Name: 7, dtype: object, 'Ham', text    [come, aftr, , &ltdecimal&gt, cleaning, house]
# Name: 8, dtype: object, 'Ham', text    [arms, fine, how's, cardiff, uni, ]
# Name: 9, dtype: object, 'Ham', text    [miles, smiles, r, made, frm, letters, u, know...
# Name: 10, dtype: object, 'Ham', text    [even, friend, priest, call]
# Name: 11, dtype: object, 'Spam', text    [(, oh, well, c, u, later]
# Name: 12, dtype: object, 'Ham', text    [aight, i'm, chillin, friend's, room, text, way]
# Name: 13, dtype: object, 'Ham', text    [free, 1st, week, entry, 2, textpod, 4, chance...
# Name: 14, dtype: object, 'Spam', text    [ok, problem, yup, i'm, going, sch, 4, rem, co...
# Name: 15, dtype: object, 'Ham', text    [are, still, playing, gautham]
# Name: 16, dtype: object, 'Ham', text    [not, possession, especially, first, offense]
# Name: 17, dtype: object, 'Ham', text    [wifehow, knew, time, murder, exactly]
# Name: 18, dtype: object, 'Ham', text    [i'm, already, back, home, probably]
# Name: 19, dtype: object, 'Ham', text    [email, alertfrom:, jeri, stewartsize:, 2kbsub...
# Name: 20, dtype: object, 'Spam', text    [lemme, know]
# Name: 21, dtype: object, 'Ham', text    [aiyah, ok, wat, long, got, improve, already, ...
# Name: 22, dtype: object, 'Ham', text    [\hi, kate, lovely, see, tonight, ill, phone, ...
# Name: 23, dtype: object, 'Ham', text    [hi, wkend, ok, journey, terrible, wk, good, h...
# Name: 24, dtype: object, 'Ham', text    [ok]
# Name: 25, dtype: object, 'Ham', text    [rose, needs, water, season, needs, change, po...
# Name: 26, dtype: object, 'Ham', text    [you, know, hook, means, right]
# Name: 27, dtype: object, 'Ham', text    [long, i, quit, i, get, like, 5, minutes, day]
# Name: 28, dtype: object, 'Ham', text    [got, seventeen, pounds, seven, hundred, ml, ...
# Name: 29, dtype: object, 'Ham', text    [at, what, time, come, tomorrow]
# Name: 30, dtype: object, 'Ham', text    [then, you, eldest, know]
# Name: 31, dtype: object, 'Ham', text    [i, wud, never, mind, u, dont, miss, u, dont, ...
# Name: 32, dtype: object, 'Ham', text    [yup, ok]
# Name: 33, dtype: object, 'Ham', text    [are, plans, family, set, stone, ]
# Name: 34, dtype: object, 'Ham', text    [i, want, send, something, sell, fast, , &lt&g...
# Name: 35, dtype: object, 'Ham', text    [did, either, idea's, do, know, anyplaces, som...
# Name: 36, dtype: object, 'Ham', text    [your, gonna, death, i'm, gonna, leave, note, ...
# Name: 37, dtype: object, 'Ham', text    [ok, lar, joking, wif, u, oni]
# Name: 38, dtype: object, 'Ham', text    [the, guy, (kadeem), selling, since, break, i,...
# Name: 39, dtype: object, 'Ham', text    [nicenicehow, working]
# Name: 40, dtype: object, 'Ham', text    [sorry, i, flaked, last, night, shit's, seriou...
# Name: 41, dtype: object, 'Ham', text    [ummmmmaah, many, many, happy, returns, day, d...
# Name: 42, dtype: object, 'Ham', text    [dont, hesitate, you, know, second, time, weak...
# Name: 43, dtype: object, 'Ham', text    [once, free, call, sir, i, waiting]
# Name: 44, dtype: object, 'Ham', text    [ugh, leg, hurts, musta, overdid, mon]
# Name: 45, dtype: object, 'Ham', text    [just, getting, back, home]
# Name: 46, dtype: object, 'Ham', text    [you, always, make, things, bigger]
# Name: 47, dtype: object, 'Ham', text    [what, time, think, need, know, i, near, campus]
# Name: 48, dtype: object, 'Ham', text    [ya, ok, dinner]
# Name: 49, dtype: object, 'Ham', text    [dude, u, knw, also, teluguthts, gudk, gud, nyt]
# Name: 50, dtype: object, 'Ham', text    [ur, awarded, city, break, could, win, å200, s...
# Name: 51, dtype: object, 'Spam', text    [no, get, headache, trying, figure, u, trust, ...
# Name: 52, dtype: object, 'Ham', text    [yeah, i, i'll, leave, maybe, 7ish]
# Name: 53, dtype: object, 'Ham', text    [make, 3, 4, fucks, sake, x]
# Name: 54, dtype: object, 'Ham', text    [hi, ||, do, u, want, |, join, sts, later, ||,...
# Name: 55, dtype: object, 'Ham', text    [carlos'll, minute, still, need, buy]
# Name: 56, dtype: object, 'Ham', text    [erutupalam, thandiyachu]
# Name: 57, dtype: object, 'I dont know', text    [wishing, family, merry, \x\", mas, happy, new...
# Name: 58, dtype: object, 'Ham', text    [simply, sitting, watching, match, office]
# Name: 59, dtype: object, 'Ham', text    [nah, straight, bring, bud, drinks, something,...
# Name: 60, dtype: object, 'Ham', text    [awesome, i, remember, last, time, got, somebo...
# Name: 61, dtype: object, 'Ham', text    [draw, vai, dont, think, so:)]
# Name: 62, dtype: object, 'Ham', text    [package, programs, well]
# Name: 63, dtype: object, 'Ham', text    [ok]
# Name: 64, dtype: object, 'Ham', text    [yeah, that's, impression, i, got]
# Name: 65, dtype: object, 'Ham', text    [alex, knows, guy, sells, mids, he's, south, t...
# Name: 66, dtype: object, 'Ham', text    [free, unlimited, hardcore, porn, direct, 2, m...
# Name: 67, dtype: object, 'Spam', text    [did, get, gift, this, year, didnt, get, anyth...
# Name: 68, dtype: object, 'Ham', text    [don't, worry, , easy, ingredients]
# Name: 69, dtype: object, 'Ham', text    [i, cant, pick, phone, right, pls, send, message]
# Name: 70, dtype: object, 'Ham', text    [yes, i, care, cause, i, know]
# Name: 71, dtype: object, 'Ham', text    [sorry, completely, forgot, , pop, em, round, ...
# Name: 72, dtype: object, 'Ham', text    [urgent, you, 1, week, free, membership, å1000...
# Name: 73, dtype: object, 'Spam', text    [didn't, get, hep, b, immunisation, nigeria]
# Name: 74, dtype: object, 'Ham', text    [todays, vodafone, numbers, ending, 4882, sele...
# Name: 75, dtype: object, 'Spam', text    [lol, oops, sorry, have, fun, ]
# Name: 76, dtype: object, 'Ham', text    [nah, i, think, goes, usf, lives, around, though]
# Name: 77, dtype: object, 'Ham', text    [ranjith, cal, drpd, deeraj, deepak, 5min, hold]
# Name: 78, dtype: object, 'Ham', text    [nan, sonathaya, soladha, why, boss]
# Name: 79, dtype: object, 'Ham', text    [dear, voucher, holder, 2, claim, 1st, class, ...
# Name: 80, dtype: object, 'Ham', text    [er, mw, im, filled, tuth, aight]
# Name: 81, dtype: object, 'Ham', text    [yes, baby, we, study, positions, kama, sutra, )]
# Name: 82, dtype: object, 'Ham', text    [sorry, left, phone, upstairs, ok, might, hect...
# Name: 83, dtype: object, 'Ham', text    [want, grasp, pretty, booty, :)]
# Name: 84, dtype: object, 'Ham', text    [i, gentle, baby, soon, taking, , &lt&gt, , in...
# Name: 85, dtype: object, 'Ham', text    [dude, like, buff, wind]
# Name: 86, dtype: object, 'Ham', text    [so, samus, shoulders, yet]
# Name: 87, dtype: object, 'Ham', text    [dear, dave, final, notice, collect, 4, teneri...
# Name: 88, dtype: object, 'Spam', text    [tell, friends, plan, valentines, day, , &ltur...
# Name: 89, dtype: object, 'Ham', text    [please, give, 2, , pick, tuesday, evening, 8,...
# Name: 90, dtype: object, 'Ham', text    [k, addie, &amp, i, art, i'll, get, home]
# Name: 91, dtype: object, 'Ham', text    [you, winner, u, specially, selected, 2, recei...
# Name: 92, dtype: object, 'Ham', text    [havent, mus, ask, u, 1st, wat, of, meet, 4, l...
# Name: 93, dtype: object, 'Ham', text    [sry, dajst, nw, came, home]
# Name: 94, dtype: object, 'Ham', text    [ok, pa, nothing, problem:)]
# Name: 95, dtype: object, 'Ham', text    [might, ax, well, im]
# Name: 96, dtype: object, 'Ham', text    [mon, okie, lor, haha, best, cheap, n, gd, foo...
# Name: 97, dtype: object, 'Ham', text    [k, makes, sense, btw, carlos, difficult, guys...
# Name: 98, dtype: object, 'Ham', text    [\wen, u, miss, someone]
# Name: 99, dtype: object, 'Ham', text    [its, valentine, game, , , send, dis, msg, ur,...
# Name: 100, dtype: object, 'Ham', text    [ss:)i, thinl, role, like, sachinjust, standin...
# Name: 101, dtype: object, 'Ham', text    [i, told, i, dr, appt, next, week, she, thinks...
# Name: 102, dtype: object, 'Ham', text    [you, get, chicken, broth, want, ramen, unless...
# Name: 103, dtype: object, 'Ham', text    [there, r, many, modelsony, ericson, also, der...
# Name: 104, dtype: object, 'Ham', text    [one, small, prestige, problem]
# Name: 105, dtype: object, 'Ham', text    [hey, what's, charles, sorry, late, reply]
# Name: 106, dtype: object, 'Ham', text    [just, sing, hu, i, think, also, important, fi...
# Name: 107, dtype: object, 'Ham', text    [\hey, babe, far, 2, spunout, 2, spk, at, da, ...
# Name: 108, dtype: object, 'Ham', text    [no, screaming, means, shouting]
# Name: 109, dtype: object, 'Ham', text    [sunshine, hols, to, claim, ur, med, holiday, ...
# Name: 110, dtype: object, 'Spam', text    [got, smaller, capacity, one, quite, ex]
# Name: 111, dtype: object, 'Ham', text    [mum, say, wan, go, go, then, shun, bian, watc...
# Name: 112, dtype: object, 'Ham', text    [\cheers, for, callin, babesozi, culdnt, talkb...
# Name: 113, dtype: object, 'Ham', text    [i, (career, tel), added, u, contact, indyaroc...
# Name: 114, dtype: object, 'Ham', text    [all, done, all, handed, celebrations, full, s...
# Name: 115, dtype: object, 'Ham', text    [sorry, de, went, shop]
# Name: 116, dtype: object, 'Ham', text    [i, waiting, call, sir]
# Name: 117, dtype: object, 'Ham', text    [noooooooo, please, last, thing, i, need, stre...
# Name: 118, dtype: object, 'Ham', text    [understand, loss, gain, :), work, school]
# Name: 119, dtype: object, 'Ham', text    [i, place, ur, points, e, cultures, module, al...
# Name: 120, dtype: object, 'Ham', text    [i, think, û_thanks, see, tomo]
# Name: 121, dtype: object, 'Ham', text    [what, time, i, tell, friend, around]
# Name: 122, dtype: object, 'Ham', text    [too, late, i, said, website, i, dont, slippers]
# Name: 123, dtype: object, 'Ham', text    [iû÷m, going, try, 2, months, ha, ha, joking]
# Name: 124, dtype: object, 'Ham', text    [ur, hmv, quiz, cashbalance, currently, å500, ...
# Name: 125, dtype: object, 'Ham', text    [it, vl, bcum, difficult]
# Name: 126, dtype: object, 'Ham', text    [k, sure, relatives, home, sms, de, pls:)]
# Name: 127, dtype: object, 'Ham', text    [ìï, got, wat, buy, tell, us, ì_, need, come]
# Name: 128, dtype: object, 'Ham', text    [you, contacted, dating, service, someone, kno...
# Name: 129, dtype: object, 'Ham', text    [i, know, people, still, town]
# Name: 130, dtype: object, 'Ham', text    [she, said'', u, mind, i, go, bedroom, minute,...
# Name: 131, dtype: object, 'Ham', text    [gud, mrng, dear, hav, nice, day]
# Name: 132, dtype: object, 'Ham', text    [oh, :)only, 4, outside, players, allowed, pla...
# Name: 133, dtype: object, 'Ham', text    [am, film, ill, call, later]
# Name: 134, dtype: object, 'Ham', text    [are, castor, you, need, see, something]
# Name: 135, dtype: object, 'Ham', text    [nt, driving, even, many, reasons, called, bbd...
# Name: 136, dtype: object, 'Ham', text    [chile, please, it's, , &ltdecimal&gt, , hour,...
# Name: 137, dtype: object, 'Ham', text    [\hi, darlin, youphone, im, athome, youwanna, ...
# Name: 138, dtype: object, 'Ham', text    [now, started, dont, stop, just, pray, good, i...
# Name: 139, dtype: object, 'Ham', text    [audrie, lousy, autocorrect]
# Name: 140, dtype: object, 'Ham', text    [my, planning, usually, stops, \find, hella, w...
# Name: 141, dtype: object, 'Ham', text    [say, slowly, godi, love, you, &amp, i, need, ...
# Name: 142, dtype: object, 'Ham', text    [but, dint, touch]
# Name: 143, dtype: object, 'Ham', text    [you're, gonna, way, specific]
# Name: 144, dtype: object, 'Ham', text    [lol, enjoy, role, playing, much]
# Name: 145, dtype: object, 'Ham', text    [valentines, day, special, win, å1000, quiz, t...
# Name: 146, dtype: object, 'Ham', text    [okey, doke, i'm, home, dressed, cos, laying, ...
# Name: 147, dtype: object, 'Ham', text    [hi, you, spoke, maneesha, v, we'd, like, know...
# Name: 148, dtype: object, 'Ham', text    [do, u, still, plumbers, tape, wrench, could, ...
# Name: 149, dtype: object, 'Ham', text    [i, dont, can, send, plus, how's, mode]
# Name: 150, dtype: object, 'Ham', text    [ok, vldo, u, know, got, adsense, approved]
# Name: 151, dtype: object, 'Ham', text    [prepare, pounded, every, night]
# Name: 152, dtype: object, 'Ham', text    [well, boy, i, glad, g, wasted, night, applebe...
# Name: 153, dtype: object, 'Ham', text    [nah, im, goin, 2, wrks, j, wot, bout, u]
# Name: 154, dtype: object, 'Ham', text    [now, reached, home, , , i, tired, , i, come, ...
# Name: 155, dtype: object, 'Ham', text    [i, think, far, find, check, google, maps, pla...
# Name: 156, dtype: object, 'Ham', text    [hey, you, got, mail]
# Name: 157, dtype: object, 'Ham', text    [yes, i'm, small, kid, and, boost, secret, ene...
# Name: 158, dtype: object, 'Ham', text    [how, much, eighth]
# Name: 159, dtype: object, 'Ham', text    [and, princess, :)]
# Name: 160, dtype: object, 'Ham', text    [reminder, from, o2:, to, get, 250, pounds, fr...
# Name: 161, dtype: object, 'Ham', text    [mum, going, robinson, already]
# Name: 162, dtype: object, 'Ham', text    [lyricalladie(21f), inviting, friend, reply, y...
# Name: 163, dtype: object, 'Spam', text    [nothing, splwat, abt, u, whr, ru]
# Name: 164, dtype: object, 'Ham', text    [then, u, better, go, sleep, dun, disturb, u, ...
# Name: 165, dtype: object, 'Ham', text    [well, must, pain, catch]
# Name: 166, dtype: object, 'Ham', text    [i, love, you, set, soul, fire, it, spark, but...
# Name: 167, dtype: object, 'Ham', text    [wat's, dear, sleeping, ah]
# Name: 168, dtype: object, 'Ham', text    [ok, lor]
# Name: 169, dtype: object, 'Ham', text    [hey, really, pretty, late, you, want, go, les...
# Name: 170, dtype: object, 'Ham', text    [we, know, someone, know, fancies, call, 09058...
# Name: 171, dtype: object, 'Ham', text    [lol, i, could, starve, lose, pound, end, day]
# Name: 172, dtype: object, 'Ham', text    [what, pa, tell, i, went, bath:)]
# Name: 173, dtype: object, 'Ham', text    [solve, case, :, a, man, was, found, murdered,...
# Name: 174, dtype: object, 'Ham', text    [:(, that's, v, romantic]
# Name: 175, dtype: object, 'Ham', text    [i, anything, lor]
# Name: 176, dtype: object, 'Ham', text    [do, always, celebrate, ny's, family, ]
# Name: 177, dtype: object, 'Ham', text    [hi, baby, im, sat, bloody, bus, mo, wont, hom...
# Name: 178, dtype: object, 'Ham', text    [send, ur, friends, receive, something, ur, vo...
# Name: 179, dtype: object, 'Ham', text    [yo, jp, hungry, like, mofo]
# Name: 180, dtype: object, 'Ham', text    [love, aathilove, u, lot]
# Name: 181, dtype: object, 'Ham', text    [guess, somebody, know, secretly, fancies, wan...
# Name: 182, dtype: object, 'Ham', text    [okay, name, ur, price, long, legal, wen, i, p...
# Name: 183, dtype: object, 'Ham', text    [how, its, ages, how's, abj]
# Name: 184, dtype: object, 'Ham', text    [free, msg:, ringtonefrom:, http:tms, widelive...
# Name: 185, dtype: object, 'Spam', text    [wa, u, efficient, gee, thanx]
# Name: 186, dtype: object, 'Ham', text    [heehee, funny, tho]
# Name: 187, dtype: object, 'Ham', text    [urgh, coach, hot, smells, chip, fat, thanks, ...
# Name: 188, dtype: object, 'Ham', text    [jane, babes, goin, 2, wrk, feel, ill, lst, ni...
# Name: 189, dtype: object, 'Ham', text    [complimentary, 4, star, ibiza, holiday, å1000...
# Name: 190, dtype: object, 'Spam', text    [also, track, lighters, find]
# Name: 191, dtype: object, 'Ham', text    [i, want, show, world, princess, :), europe]
# Name: 192, dtype: object, 'Ham', text    [text, way, cup, stop, work, and, bus]
# Name: 193, dtype: object, 'Ham', text    [ok, also, wan, 2, watch, e, 9, pm, show]
# Name: 194, dtype: object, 'Ham', text    [nobody, decide, eat, dad, wants, chinese]
# Name: 195, dtype: object, 'Ham', text    [haha, mayb, u're, rite, u, know, well, da, fe...
# Name: 196, dtype: object, 'Ham', text    [i, waiting, machan, call, free]
# Name: 197, dtype: object, 'Ham', text    [it, could, work, we'll, reach, consensus, nex...
# Name: 198, dtype: object, 'Ham', text    [you, made, day, do, great, day]
# Name: 199, dtype: object, 'Ham', text    [nah, wednesday, when, i, bring, mini, cheetos...
# Name: 200, dtype: object, 'Ham', text    [important, information, 4, orange, user, 0789...
# Name: 201, dtype: object, 'Ham', text    [buy, space, invaders, 4, chance, 2, win, orig...
# Name: 202, dtype: object, 'Ham', text    [87077:, kick, new, season, 2wks, free, goals,...
# Name: 203, dtype: object, 'Spam', text    [now, i'm, going, lunch]
# Name: 204, dtype: object, 'Ham', text    [orange, customer, may, claim, free, camera, p...
# Name: 205, dtype: object, 'Spam', text    [had, mobile, 11, months, u, r, entitled, upda...
# Name: 206, dtype: object, 'Ham', text    [4, tacos, , 1, rajas, burrito, right]
# Name: 207, dtype: object, 'Ham', text    [ki, send, , &lt&gt, , min:)]
# Name: 208, dtype: object, 'Ham', text    [hi, mobile, , &lt&gt, , added, contact, list,...
# Name: 209, dtype: object, 'Ham', text    [now, whats, house, , , and, beer, ]
# Name: 210, dtype: object, 'Ham', text    [no, i'm, boat, still, moms, check, yo, i'm, h...
# Name: 211, dtype: object, 'Ham', text    [sorry, i'll, call, later]
# Name: 212, dtype: object, 'Ham', text    [u, sick, still, go, shopping]
# Name: 213, dtype: object, 'Ham', text    [hows, watch, resizing]
# Name: 214, dtype: object, 'Ham', text    [no, dude, fakemy, frnds, got, money, thts, i'...
# Name: 215, dtype: object, 'Ham', text    [and, way, send, shade's, stuff, and, wonderful]
# Name: 216, dtype: object, 'Ham', text    [u, call]
# Name: 217, dtype: object, 'Ham', text    [cool, text, head]
# Name: 218, dtype: object, 'Ham', text    [whats, coming, hill, is, monster, hope, great...
# Name: 219, dtype: object, 'Ham', text    [oic, i, saw, tot, din, c, i, found, group, liao]
# Name: 220, dtype: object, 'Ham', text    [\ey, calm, downon, theacusations, itxt, u, co...
# Name: 221, dtype: object, 'Ham', text    [remind, get, i, shall]
# Name: 222, dtype: object, 'Ham', text    [ok]
# Name: 223, dtype: object, 'Ham', text    [when, get, library]
# Name: 224, dtype: object, 'Ham', text    [hmm, yeah, grooved, and, im, looking, forward...
# Name: 225, dtype: object, 'Ham', text    [ok, there, may, free, gym]
# Name: 226, dtype: object, 'Ham', text    [oh, which, brand]
# Name: 227, dtype: object, 'Ham', text    [hey, i've, booked, pilates, yoga, lesson, alr...
# Name: 228, dtype: object, 'Ham', text    [hey, girl, how, r, u, hope, u, r, well, me, a...
# Name: 229, dtype: object, 'Ham', text    [hey, happen, de, are, alright]
# Name: 230, dtype: object, 'Ham', text    [nothing, ever, easy, but, looking, reason, ta...
# Name: 231, dtype: object, 'Ham', text    [reverse, cheating, that, mathematics]
# Name: 232, dtype: object, 'Ham', text    [same, i, consider, walls, bunkers, shit, impo...
# Name: 233, dtype: object, 'Ham', text    [we, pizza, u, want]
# Name: 234, dtype: object, 'Ham', text    [you, receiving, week's, triple, echo, rington...
# Name: 235, dtype: object, 'Ham', text    [please, call, 08712402902, immediately, urgen...
# Name: 236, dtype: object, 'Spam', text    [sorryin, meeting, i'll, call, later]
# Name: 237, dtype: object, 'Ham', text    [free, 1st, week, no1, nokia, tone, 4, ur, mob...
# Name: 238, dtype: object, 'Ham', text    [no, objection, my, bf, coming]
# Name: 239, dtype: object, 'Ham', text    [hi, email, address, changed, ]
# Name: 240, dtype: object, 'Ham', text    [yup, i'm, free]
# Name: 241, dtype: object, 'Ham', text    [hi, princess, thank, pics, you, pretty, how]
# Name: 242, dtype: object, 'Ham', text    [lol, would, awesome, payback]
# Name: 243, dtype: object, 'Ham', text    [urgent, call, 09066612661, landline, your, co...
# Name: 244, dtype: object, 'Spam', text    [100, dating, service, call, 09064012103, box3...
# Name: 245, dtype: object, 'Spam', text    [our, dating, service, asked, 2, contact, u, s...
# Name: 246, dtype: object, 'Ham', text    [i, went, project, centre]
# Name: 247, dtype: object, 'Ham', text    [sorry, took, long, omw]
# Name: 248, dtype: object, 'Ham', text    [in, fact, leave, i, think, addie, goes, back,...
# Name: 249, dtype: object, 'Ham', text    [great, i'm, church, holla, get]
# Name: 250, dtype: object, 'Ham', text    [ok, u, tell, wat, time, u, coming, later, lor]
# Name: 251, dtype: object, 'Ham', text    [hey, happy, birthday]
# Name: 252, dtype: object, 'Ham', text    [yo, way, could, pick, something, tonight]
# Name: 253, dtype: object, 'Ham', text    [dear, got, bus, directly, calicut]
# Name: 254, dtype: object, 'Ham', text    [erm, û_, ill, pick, 645pm, that'll, give, en...
# Name: 255, dtype: object, 'Ham', text    [ela, kanoil, download, come, wen, ur, free]
# Name: 256, dtype: object, 'Ham', text    [hi, harish's, rent, transfred, ur, acnt]
# Name: 257, dtype: object, 'Ham', text    [tadaaaaa, i, home, babe, still, ]
# Name: 258, dtype: object, 'Ham', text    [nooooooo, i'm, gonna, bored, death, day, cabl...
# Name: 259, dtype: object, 'Ham', text    [yup]
# Name: 260, dtype: object, 'Ham', text    [, was, thinking, chuckin, ur, red, green, n, ...
# Name: 261, dtype: object, 'Ham', text    [freemsg>fav, xmas, tonesreply, real]
# Name: 262, dtype: object, 'Ham', text    [you, everywhere, dirt, floor, windows, even, ...
# Name: 263, dtype: object, 'Ham', text    [hahahause, brain, dear]
# Name: 264, dtype: object, 'Ham', text    [but, pls, dont, play, others, life]
# Name: 265, dtype: object, 'Ham', text    [wamma, get, laidwant, real, doggin, locations...
# Name: 266, dtype: object, 'Spam', text    [not, thought, bout, ||, drink, tap, &, spile,...
# Name: 267, dtype: object, 'Ham', text    [no, ill, meet, library]
# Name: 268, dtype: object, 'Ham', text    [otherwise, part, time, job, natuition]
# Name: 269, dtype: object, 'Ham', text    [night, night, see, tomorrow]
# Name: 270, dtype: object, 'Ham', text    [just, wait, till, end, march, el, nino, gets,...
# Name: 271, dtype: object, 'Ham', text    [what, time, thinkin, goin]
# Name: 272, dtype: object, 'Ham', text    [i, send, pic, like, :)]
# Name: 273, dtype: object, 'Ham', text    [i'll, see, i, swing, bit, got, things, take, ...
# Name: 274, dtype: object, 'Ham', text    [got, fujitsu, ibm, hp, toshiba, got, lot, mod...
# Name: 275, dtype: object, 'Ham', text    [dunno, da, next, show, aft, 6, 850, toa, payo...
# Name: 276, dtype: object, 'Ham', text    [wait, know, wesleys, town, i, bet, hella, drugs]
# Name: 277, dtype: object, 'Ham', text    [k, i'll, work, something]
# Name: 278, dtype: object, 'Ham', text    [goodo, yes, must, speak, friday, , eggpotato,...
# Name: 279, dtype: object, 'Ham', text    [jay's, getting, really, impatient, belligerent]
# Name: 280, dtype: object, 'Ham', text    [there, generally, one, it's, uncountable, nou...
# Name: 281, dtype: object, 'Ham', text    [ok, lor]
# Name: 282, dtype: object, 'Ham', text    [i, know, grumpy, old, people, my, mom, like, ...
# Name: 283, dtype: object, 'Ham', text    [hey, boys, want, hot, xxx, pics, sent, direct...
# Name: 284, dtype: object, 'Ham', text    [what, told, tell, stupid, hear, wont, tell, a...
# Name: 285, dtype: object, 'Ham', text    [i, rather, prominent, bite, mark, right, cheek]
# Name: 286, dtype: object, 'Ham', text    [still, area, restaurant, ill, try, come, back...
# Name: 287, dtype: object, 'Ham', text    [yeah, got, one, lined, us]
# Name: 288, dtype: object, 'Ham', text    [we, fine, thanks]
# Name: 289, dtype: object, 'Ham', text    [do, whatever, want, you, know, rules, we, tal...
# Name: 290, dtype: object, 'Ham', text    [ok, ksry, knw, 2, sivatats, askd]
# Name: 291, dtype: object, 'Ham', text    [i, wnt, buy, bmw, car, urgentlyits, vry, urge...
# Name: 292, dtype: object, 'Ham', text    [sorry, man, accidentally, left, phone, silent...
# Name: 293, dtype: object, 'Ham', text    [ha, u, jus, ate, honey, ar, so, sweet]
# Name: 294, dtype: object, 'Ham', text    [it, happens, r, 2waxsto, wat, want, she, come...
# Name: 295, dtype: object, 'Ham', text    [is, fujitsu, series, lifebook, good]
# Name: 296, dtype: object, 'Ham', text    [buy, space, invaders, 4, chance, 2, win, orig...
# Name: 297, dtype: object, 'Ham', text    [its, ok, anybody, asks, abt, u, tel, them:p]
# Name: 298, dtype: object, 'Ham', text    [nobody, names, penis, girls, name, story, add]
# Name: 299, dtype: object, 'Ham', text    [i, asked, sen, come, chennai, search, job]
# Name: 300, dtype: object, 'Ham', text    [mark, works, tomorrow, he, gets, 5, his, work...
# Name: 301, dtype: object, 'Ham', text    [havent]
# Name: 302, dtype: object, 'Ham', text    [sms, services, inclusive, text, credits, pls,...
# Name: 303, dtype: object, 'Spam', text    [lol, ok, ill, try, send, be, warned, sprint, ...
# Name: 304, dtype: object, 'Ham', text    [wow, the, boys, r, back, take, that, 2007, uk...
# Name: 305, dtype: object, 'Ham', text    [aight, well, keep, informed]
# Name: 306, dtype: object, 'Ham', text    [ok, ill, right, later]
# Name: 307, dtype: object, 'Ham', text    [i, want, sent, , &lt&gt, mesages, today, that...
# Name: 308, dtype: object, 'Ham', text    [just, got, , &lt&gt]
# Name: 309, dtype: object, 'Ham', text    [so, really, what, how's, masters, and]
# Name: 310, dtype: object, 'Ham', text    [want, finally, lunch, today]
# Name: 311, dtype: object, 'Ham', text    [ah, well, confuses, things, doesnû÷t]
# Name: 312, dtype: object, 'Ham', text    [u, secret, admirer, looking, 2, make, contact...
# Name: 313, dtype: object, 'Ham', text    [she, sister, she, belongs, 2, family, she, ho...
# Name: 314, dtype: object, 'Ham', text    [pls, dont, restrict, eating, anythin, likes, ...
# Name: 315, dtype: object, 'Ham', text    [hiya, , u, paying, money, account, if, thanks...
# Name: 316, dtype: object, 'Ham', text    [why, keeping, away, like]
# Name: 317, dtype: object, 'Ham', text    [thank, you, callingforgot, say, happy, onam, ...
# Name: 318, dtype: object, 'Ham', text    [what, happen, dear, why, silent, i, tensed]
# Name: 319, dtype: object, 'Ham', text    [, number, u, live, is, 11]
# Name: 320, dtype: object, 'Ham', text    [oh, howda, gud, gud, mathe, en, samachara, ch...
# Name: 321, dtype: object, 'Ham', text    [this, pay, , &ltdecimal&gt, , lakhs:)]
# Name: 322, dtype: object, 'Ham', text    [no, go, no, openings, room, 'til, thanksgivin...
# Name: 323, dtype: object, 'Ham', text    [i, sent, maga, money, yesterday, oh]
# Name: 324, dtype: object, 'Ham', text    [urgent, your, mobile, number, awarded, å2000,...
# Name: 325, dtype: object, 'Spam', text    [you, come, life, brought, sun, shiny, warming...
# Name: 326, dtype: object, 'Ham', text    [i'm, meeting, call, later]
# Name: 327, dtype: object, 'Ham', text    [do, know, god, created, gap, fingers, so, one...
# Name: 328, dtype: object, 'Ham', text    [hmm, thinking, lor]
# Name: 329, dtype: object, 'Ham', text    [mm, food, da]
# Name: 330, dtype: object, 'Ham', text    [he, fucking, chickened, he, messaged, would, ...
# Name: 331, dtype: object, 'Ham', text    [you, busy, i, come, point, figure, we're, tom...
# Name: 332, dtype: object, 'Ham', text    [boo, how's, things, i'm, back, home, little, ...
# Name: 333, dtype: object, 'Ham', text    [that's, cool, he'll, night, lemme, know, around]
# Name: 334, dtype: object, 'Ham', text    [shall, come, get, pickle]
# Name: 335, dtype: object, 'Ham', text    [for, ur, chance, win, å250, cash, every, wk, ...
# Name: 336, dtype: object, 'Spam', text    [gent, we, trying, contact, last, weekends, dr...
# Name: 337, dtype: object, 'Ham', text    [i'm, awake, oh, what's]
# Name: 338, dtype: object, 'Ham', text    [wn, u, r, hurt, prsn, close, 2, u, fight, wit...
# Name: 339, dtype: object, 'Ham', text    [so, means, still, think, teju]
# Name: 340, dtype: object, 'Ham', text    [still, otside, leu, come, 2morrow, maga]
# Name: 341, dtype: object, 'Ham', text    [sian, aft, meeting, supervisor, got, work, 2,...
# Name: 342, dtype: object, 'Ham', text    [hey, late, i'm, amk, need, drink, tea, coffee]
# Name: 343, dtype: object, 'Ham', text    [had, mobile, 10, mths, update, latest, camera...
# Name: 344, dtype: object, 'Spam', text    [aight, i, plan, come, later, tonight]
# Name: 345, dtype: object, 'Ham', text    [sorry, mates, phone, didnt, write, love, kate]
# Name: 346, dtype: object, 'Ham', text    [hmmmbut, give, one, day]
# Name: 347, dtype: object, 'Ham', text    [ok, set, let, u, noe, e, details, later]
# Name: 348, dtype: object, 'Ham', text    [well, know, z, take, care, so, worries]
# Name: 349, dtype: object, 'Ham', text    [i, know, u, u, know, send, chat, 86688, let's...
# Name: 350, dtype: object, 'Ham', text    [sunshine, hols, to, claim, ur, med, holiday, ...
# Name: 351, dtype: object, 'Spam', text    [yetunde, i'm, sorry, moji, seem, busy, able, ...
# Name: 352, dtype: object, 'Ham', text    [hows, pain, deary, r, u, smiling]
# Name: 353, dtype: object, 'Ham', text    [hi, we, moved, in2, pub, , would, great, 2, c...
# Name: 354, dtype: object, 'Ham', text    [no, dice, art, class, 6, thru, 9, :(, thanks,...
# Name: 355, dtype: object, 'Ham', text    [sounds, like, could, lot, time, spent, chasti...
# Name: 356, dtype: object, 'Ham', text    [well, weather, cali's, great, but, complexiti...
# Name: 357, dtype: object, 'Ham', text    [mmmmm, , it, sooooo, good, wake, words, morni...
# Name: 358, dtype: object, 'Ham', text    [i, want, see, pretty, pussy]
# Name: 359, dtype: object, 'Ham', text    [hi, sexychat, girls, waiting, text, text, gre...
# Name: 360, dtype: object, 'Ham', text    [two, teams, waiting, players]
# Name: 361, dtype: object, 'Ham', text    [well, done, , luv, ya, ]
# Name: 362, dtype: object, 'Ham', text    [gwr]
# Name: 363, dtype: object, 'I dont know', text    [yeah, i, see]
# Name: 364, dtype: object, 'Ham', text    [well, great, weekend]
# Name: 365, dtype: object, 'Ham', text    [men, always, needs, beautiful, intelligent, c...
# Name: 366, dtype: object, 'Ham', text    [anyway, i, think, i, secure, anything, lemme,...
# Name: 367, dtype: object, 'Ham', text    [win, newest, åòharry, potter, order, phoenix,...
# Name: 368, dtype: object, 'Ham', text    [umma, life, vava, umma, love, lot, dear]
# Name: 369, dtype: object, 'Ham', text    [i, reach, ur, home, , &lt&gt, , minutes]
# Name: 370, dtype: object, 'Ham', text    [i'm, glad, you, following, dreams]
# Name: 371, dtype: object, 'Ham', text    [lol, nah, bad, thanks, its, good, b, home, qu...
# Name: 372, dtype: object, 'Ham', text    [our, records, indicate, u, maybe, entitled, 5...
# Name: 373, dtype: object, 'Ham', text    [good, afternoon, babe, how, goes, day, , any,...
# Name: 374, dtype: object, 'Ham', text    [yeah, worse]
# Name: 375, dtype: object, 'Ham', text    [please, call, 08712402578, immediately, urgen...
# Name: 376, dtype: object, 'Spam', text    [nah, can't, help, i've, never, iphone]
# Name: 377, dtype: object, 'Ham', text    [wifehow, knew, time, murder, exactly]
# Name: 378, dtype: object, 'Ham', text    [i, take, care, financial, problemi, help:)]
# Name: 379, dtype: object, 'Ham', text    [, &lt&gt, , mca, but, conform]
# Name: 380, dtype: object, 'Ham', text    [do, know, lab, goggles, went]
# Name: 381, dtype: object, 'Ham', text    [i, haf, msn, it's, yijuehotmailcom]
# Name: 382, dtype: object, 'Ham', text    [dear, good, morning]
# Name: 383, dtype: object, 'Ham', text    [yo, dude, guess, got, arrested, day]
# Name: 384, dtype: object, 'Ham', text    [when, came, hostel]
# Name: 385, dtype: object, 'Ham', text    [probably, still, going, stuff]
# Name: 386, dtype: object, 'Ham', text    [feel, yourself, that, you, are, always, happy...
# Name: 387, dtype: object, 'Ham', text    [are, sure, mean, \get]
# Name: 388, dtype: object, 'Ham', text    [i'm, coming, home, 4, dinner]
# Name: 389, dtype: object, 'Ham', text    [oh, getting, even, u, u]
# Name: 390, dtype: object, 'Ham', text    [yeah, where's, class]
# Name: 391, dtype: object, 'Ham', text    [free, entry, 2, wkly, comp, win, fa, cup, fin...
# Name: 392, dtype: object, 'Spam', text    [i, think, asking, gym, excuse, lazy, people, ...
# Name: 393, dtype: object, 'Ham', text    [so, u, workin, overtime, nigpun]
# Name: 394, dtype: object, 'Ham', text    [reverse, cheating, that, mathematics]
# Name: 395, dtype: object, 'Ham', text    [ill, b, down, soon]
# Name: 396, dtype: object, 'Ham', text    [if, want, mapquest, something, look, \usf, do...
# Name: 397, dtype: object, 'Ham', text    [kaiez, enjoy, ur, tuition, gee, thk, e, secon...
# Name: 398, dtype: object, 'Ham', text    [new, theory:, argument, wins, situation, lose...
# Name: 399, dtype: object, 'Ham', text    [we, currently, message, awaiting, collection,...
# Name: 400, dtype: object, 'Spam', text    [what, standing]
# Name: 401, dtype: object, 'Ham', text    [anytime, lor]
# Name: 402, dtype: object, 'Ham', text    [sitting, ard, nothing, lor, u, leh, busy, w, ...
# Name: 403, dtype: object, 'Ham', text    [hot, live, fantasies, call, 08707509020, just...
# Name: 404, dtype: object, 'Spam', text    [thought, king, hill, thing]
# Name: 405, dtype: object, 'Ham', text    [dunno, lei, i, thk, mum, lazy, go, i, neva, a...
# Name: 406, dtype: object, 'Ham', text    [ok, another, number]
# Name: 407, dtype: object, 'Ham', text    [thats, cool, sometimes, slow, gentle, sonetim...
# Name: 408, dtype: object, 'Ham', text    [do, want, new, nokia, 3510i, colour, phone, d...
# Name: 409, dtype: object, 'Ham', text    [how, come, get, should, b, quite, diff, guess...
# Name: 410, dtype: object, 'Ham', text    [hello, love, , how, went, day, , are, alright...
# Name: 411, dtype: object, 'Ham', text    [height, confidence:, all, aeronautics, profes...
# Name: 412, dtype: object, 'Ham', text    [it, simple, arithmetic, percentages]
# Name: 413, dtype: object, 'Ham', text    [was, ask, will, keep, one, maybe, that's, get...
# Name: 414, dtype: object, 'Ham', text    [in, place, get, rooms, cheap:)]
# Name: 415, dtype: object, 'Ham', text    [er, yep, sure, props]
# Name: 416, dtype: object, 'Ham', text    [for, information, ikea, spelled, caps, that, ...
# Name: 417, dtype: object, 'Ham', text    [pls, give, food, preferably, pap, slowly, loa...
# Name: 418, dtype: object, 'Ham', text    [i, av, new, number, , , wil, u, use, oneta]
# Name: 419, dtype: object, 'Ham', text    [which, weird, i, know, i, one, point]
# Name: 420, dtype: object, 'Ham', text    [no, current, food, i, alone, also]
# Name: 421, dtype: object, 'Ham', text    [2p, per, min, call, germany, 08448350055, bt,...
# Name: 422, dtype: object, 'Spam', text    [my, supervisor, find, 4, one, lor, thk, stude...
# Name: 423, dtype: object, 'Ham', text    [good, evening, sir, hope, nice, day, i, wante...
# Name: 424, dtype: object, 'Ham', text    [so, is, th, gower, mate, which, is, where, i,...
# Name: 425, dtype: object, 'Ham', text    [you, said, no, problem, when, let, know]
# Name: 426, dtype: object, 'Ham', text    [you, hate, you, call, didnt, accept, even, si...
# Name: 427, dtype: object, 'Ham', text    [arun, u, transfr, amt]
# Name: 428, dtype: object, 'Ham', text    [have, seen, who's, back, holby]
# Name: 429, dtype: object, 'Ham', text    [so, ì_'ll, submitting, da, project, tmr, rite]
# Name: 430, dtype: object, 'Ham', text    [its, part, checking, iq]
# Name: 431, dtype: object, 'Ham', text    [i, dled, 3d, imp]
# Name: 432, dtype: object, 'Ham', text    [hope, great, new, semester, do, wish, best, y...
# Name: 433, dtype: object, 'Ham', text    [crazy, ar, he's, married, ìï, like, gd, looki...
# Name: 434, dtype: object, 'Ham', text    [well, watch, shrek, 3db)]
# Name: 435, dtype: object, 'Ham', text    [mmmmmmm, snuggles, deep, contented, sigh, , w...
# Name: 436, dtype: object, 'Ham', text    [promotion, number:, 8714714, , ur, awarded, c...
# Name: 437, dtype: object, 'Ham', text    [i, dont, know, exactly, could, ask, chechi]
# Name: 438, dtype: object, 'Ham', text    [aight, thanks, comin]
# Name: 439, dtype: object, 'Ham', text    [when, i, born, god, said, \oh, no, another, i...
# Name: 440, dtype: object, 'Ham', text    [ki, deleted, contact]
# Name: 441, dtype: object, 'Spam', text    [hellogorgeous, hows, u, my, fone, was, on, ch...
# Name: 442, dtype: object, 'Ham', text    [i, cant, pick, phone, right, pls, send, message]
# Name: 443, dtype: object, 'Ham', text    [would, u, fuckin, believe, didnt, know, thurs...
# Name: 444, dtype: object, 'Ham', text    [one, day, crab, running, sea, shorethe, waves...
# Name: 445, dtype: object, 'Ham', text    [yup, thk, u, oso, boring, wat]
# Name: 446, dtype: object, 'Ham', text    [ur, balance, å500, ur, next, question, is:, w...
# Name: 447, dtype: object, 'Ham', text    [xmas, prize, draws, we, trying, contact, u, t...
# Name: 448, dtype: object, 'Ham', text    [er, hello, things, didnû÷t, quite, go, plan,...
# Name: 449, dtype: object, 'Ham', text    [as, per, request, 'maangalyam, (alaipayuthe)'...
# Name: 450, dtype: object, 'Ham', text    [he, said, look, pretty, wif, long, hair, wat,...
# Name: 451, dtype: object, 'Ham', text    [buzzzz, grins, did, i, buzz, ass, buzz, chest...
# Name: 452, dtype: object, 'Ham', text    [you, won, guaranteed, å1000, cash, å2000, pri...
# Name: 453, dtype: object, 'Spam', text    [now, press, conference, da:)]
# Name: 454, dtype: object, 'Spam', text    [happy, birthday, may, u, find, ur, prince, ch...
# Name: 455, dtype: object, 'Ham', text    [maybe, find, something, else, instead]
# Name: 456, dtype: object, 'Ham', text    [yeah, i, think, use, gt, atm, register, not, ...
# Name: 457, dtype: object, 'Ham', text    [anything, lor, u, decide]
# Name: 458, dtype: object, 'Ham', text    [freemsg, hey, darling, 3, week's, word, back,...
# Name: 459, dtype: object, 'Ham', text    [no, callsmessagesmissed, calls]
# Name: 460, dtype: object, 'Ham', text    [i, think, i've, fixed, send, test, message]
# Name: 461, dtype: object, 'Ham', text    [eastenders, tv, quiz, what, flower, dot, comp...
# Name: 462, dtype: object, 'Ham', text    [bored, speed, dating, try, speedchat, txt, sp...
# Name: 463, dtype: object, 'Ham', text    [urgent, call, 09066649731from, landline, your...
# Name: 464, dtype: object, 'Spam', text    [ok, lor, or, u, wan, go, look, 4, u]
# Name: 465, dtype: object, 'Ham', text    [that, depends, how, would, like, treated, :)]
# Name: 466, dtype: object, 'Ham', text    [i, jus, hope, true, , missin, cos, i'm, reall...
# Name: 467, dtype: object, 'Ham', text    [so, wanna, gym]
# Name: 468, dtype: object, 'Ham', text    [i'm, actor, when, work, work, evening, sleep,...
# Name: 469, dtype: object, 'Ham', text    [block, breaker, comes, deluxe, format, new, f...
# Name: 470, dtype: object, 'Ham', text    [these, have, move, morphine]
# Name: 471, dtype: object, 'Ham', text    [we, pleased, inform, application, airtel, bro...
# Name: 472, dtype: object, 'Ham', text    [holy, living, christ, taking, long]
# Name: 473, dtype: object, 'Ham', text    [shhhhh, nobody, supposed, know]
# Name: 474, dtype: object, 'Ham', text    [mmm, yummy, babe, , nice, jolt, suzy]
# Name: 475, dtype: object, 'Ham', text    [money, wining, number, 946, wot, next]
# Name: 476, dtype: object, 'Ham', text    [i'm, reading, text, sent, its, meant, joke, s...
# Name: 477, dtype: object, 'Ham', text    [i, tot, u, reach, liao, he, said, tshirt]
# Name: 478, dtype: object, 'Ham', text    [your, account, refilled, successfully, inr, ,...
# Name: 479, dtype: object, 'Ham', text    [no, datoday, also, forgot]
# Name: 480, dtype: object, 'Ham', text    [u, calling, right, call, hand, phone]
# Name: 481, dtype: object, 'Ham', text    [nutter, cutter, ctter, cttergg, cttargg, ctar...
# Name: 482, dtype: object, 'Ham', text    [jesus, christ, bitch, i'm, trying, give, drug...
# Name: 483, dtype: object, 'Ham', text    [yes, please, leave, , &lt&gt, , so, , &lt&gt,...
# Name: 484, dtype: object, 'Ham', text    [can, ì_, decide, faster, cos, sis, going, hom...
# Name: 485, dtype: object, 'Ham', text    [ok, give, 5, minutes, i, think, i, see, btw, ...
# Name: 486, dtype: object, 'Ham', text    [i, way, tirupur]
# Name: 487, dtype: object, 'Ham', text    [i, think, steyn, surely, get, one, wicket:)]
# Name: 488, dtype: object, 'Ham', text    [should, buy, blackberry, bold, 2, torch, shou...
# Name: 489, dtype: object, 'Ham', text    [yes, baby, i, need, stretch, open, pussy]
# Name: 490, dtype: object, 'Ham', text    [dont, message, offer]
# Name: 491, dtype: object, 'Ham', text    [oh, ya, ya, i, remember, da, ]
# Name: 492, dtype: object, 'Ham', text    [k:)k:)what, detail, want, transferacc, enough]
# Name: 493, dtype: object, 'Ham', text    [ok, come, ur, home, half, hour]
# Name: 494, dtype: object, 'Ham', text    [that, day, ì_, say, ì_, cut, ur, hair, parago...
# Name: 495, dtype: object, 'Ham', text    [i, cant, pick, phone, right, pls, send, message]
# Name: 496, dtype: object, 'Ham', text    [i, quite, know, i, still, can't, get, hold, a...
# Name: 497, dtype: object, 'Ham', text    [dear, reach]
# Name: 498, dtype: object, 'Ham', text    [christmas, an, occasion, celebrated, reflecti...
# Name: 499, dtype: object, 'Ham', text    [i, happy, saying]
# Name: 500, dtype: object, 'Ham', text    [exactly, anyways, far, is, jide, study, visit...
# Name: 501, dtype: object, 'Ham', text    [it's, cool, last, little, getting, time, soon]
# Name: 502, dtype: object, 'Ham', text    [ur, cashbalance, currently, 500, pounds, , ma...
# Name: 503, dtype: object, 'Ham', text    [u, town, alone]
# Name: 504, dtype: object, 'Ham', text    [nope, c, ì_]
# Name: 505, dtype: object, 'Ham', text    [eerie, nokia, tones, 4u, rply, tone, title, 8...
# Name: 506, dtype: object, 'Ham', text    [i'm, really, still, tonight, babe]
# Name: 507, dtype: object, 'Ham', text    [are, staying, town, ]
# Name: 508, dtype: object, 'Ham', text    [you, place, man]
# Name: 509, dtype: object, 'Ham', text    [i, want, snow, it's, freezing, windy]
# Name: 510, dtype: object, 'Ham', text    [good, no, donû÷t, need, receiptsûówell, don...
# Name: 511, dtype: object, 'Ham', text    [come, slave, your, , going, shell, unconsciou...
# Name: 512, dtype: object, 'Ham', text    [guess, ithis, first, time, i, created, web, p...
# Name: 513, dtype: object, 'Ham', text    [then, ur, sis]
# Name: 514, dtype: object, 'Ham', text    [there's, point, hangin, mr, right, he's, maki...
# Name: 515, dtype: object, 'Ham', text    [dad, wanted, talk, apartment, i, got, late, s...
# Name: 516, dtype: object, 'Ham', text    [you, bothering, trust, answers, pls]
# Name: 517, dtype: object, 'Ham', text    [pls, what's, full, name, joke's, school, cos,...
# Name: 518, dtype: object, 'Ham', text    [also, chat, awesome, make, regular, unless, s...
# Name: 519, dtype: object, 'Ham', text    [just, nw, came, hme, da]
# Name: 520, dtype: object, 'Ham', text    [hope, scared]
# Name: 521, dtype: object, 'Ham', text    [hello, hello, hi, lou, sorry, took, long, 2, ...
# Name: 522, dtype: object, 'Ham', text    [lol, u, still, feeling, sick]
# Name: 523, dtype: object, 'Ham', text    [i, thought, slide, enough]
# Name: 524, dtype: object, 'Ham', text    [sorry, roommates, took, forever, ok, i, come]
# Name: 525, dtype: object, 'Ham', text    [yo, around, just, got, car, back]
# Name: 526, dtype: object, 'Ham', text    [i, know, thinkin, malaria, but, relax, childr...
# Name: 527, dtype: object, 'Ham', text    [ìï, eatin, later, i'm, eatin, wif, frens, lei...
# Name: 528, dtype: object, 'Ham', text    [but, i'll, b, going, 2, sch, mon, my, sis, ne...
# Name: 529, dtype: object, 'Ham', text    [lol, i, would, despite, cramps, i, like, girl]
# Name: 530, dtype: object, 'Ham', text    [u, subscribed, best, mobile, content, service...
# Name: 531, dtype: object, 'Ham', text    [oh, phone, phoned, disconnected]
# Name: 532, dtype: object, 'Ham', text    [ding, ya, break, fassyole, blacko, londn]
# Name: 533, dtype: object, 'Ham', text    [thanks, ringtone, order, reference, number, x...
# Name: 534, dtype: object, 'Spam', text    [i, come, ur, home]
# Name: 535, dtype: object, 'Ham', text    [alright, omw, gotta, change, order, half8th]
# Name: 536, dtype: object, 'Ham', text    [be, sure, check, yahoo, email, we, sent, phot...
# Name: 537, dtype: object, 'Ham', text    [u, secret, admirer, looking, 2, make, contact...
# Name: 538, dtype: object, 'Ham', text    [private, your, 2004, account, statement, 0774...
# Name: 539, dtype: object, 'Spam', text    [thanks, temales, wonderful, thank, have, grea...
# Name: 540, dtype: object, 'Ham', text    [yes, i, posted, couple, pics, fb, there's, st...
# Name: 541, dtype: object, 'Ham', text    [tell, dear, happen, why, talking, like, alian]
# Name: 542, dtype: object, 'Ham', text    [i, reach, ten, morning]
# Name: 543, dtype: object, 'Ham', text    [what, shower, baby]
# Name: 544, dtype: object, 'Ham', text    [this, 2nd, time, tried, 2, contact, u, u, 750...
# Name: 545, dtype: object, 'Ham', text    [our, prasanth, ettans, mother, passed, away, ...
# Name: 546, dtype: object, 'Ham', text    [dnt, wnt, tlk, wid, u]
# Name: 547, dtype: object, 'Ham', text    [ugh, hopefully, asus, ppl, dont, randomly, re...
# Name: 548, dtype: object, 'Ham', text    [i'll, mu, like, , &lt&gt, , seconds]
# Name: 549, dtype: object, 'Ham', text    [lolnice, i, went, fish, water]
# Name: 550, dtype: object, 'Ham', text    [yo, i'm, parents', gettin, cash, good, news:,...
# Name: 551, dtype: object, 'Ham', text    [do, spare, power, supplies]
# Name: 552, dtype: object, 'Ham', text    [ìï, say, like, dat, dun, buy, ericsson, oso, ...
# Name: 553, dtype: object, 'Ham', text    [do, nice, day, today, i, love, dearly]
# Name: 554, dtype: object, 'Ham', text    [u, ned, convince, tht, possible, witot, hurti...
# Name: 555, dtype: object, 'Ham', text    [ever, green, quote, ever, told, jerry, cartoo...
# Name: 556, dtype: object, 'Ham', text    [tonight, yeah, i'd]
# Name: 557, dtype: object, 'Ham', text    [not, directly, behind, abt, 4, rows, behind, ì_]
# Name: 558, dtype: object, 'Ham', text    [do, like, italian, food]
# Name: 559, dtype: object, 'Ham', text    [how, much, payed, suganya]
# Name: 560, dtype: object, 'Ham', text    [no, i, meant, calculation, that, , &lt&gt, un...
# Name: 561, dtype: object, 'Ham', text    [i, thk, u, dun, haf, 2, hint, e, forum, alrea...
# Name: 562, dtype: object, 'Ham', text    [oops, i'll, let, know, roommate's, done]
# Name: 563, dtype: object, 'Ham', text    [please, call, amanda, regard, renewing, upgra...
# Name: 564, dtype: object, 'Spam', text    [this, is, a, long, fuckin, showr]
# Name: 565, dtype: object, 'Ham', text    [, am, train, back, northampton, i'm, afraid]
# Name: 566, dtype: object, 'Ham', text    [ohi, asked, fun, hahatake, care, ì_]
# Name: 567, dtype: object, 'Ham', text    [yup, ok]
# Name: 568, dtype: object, 'Ham', text    [goldviking, (29m), inviting, friend, reply, y...
# Name: 569, dtype: object, 'Spam', text    [anyway, i'm, going, shopping, cos, sis, done,...
# Name: 570, dtype: object, 'Ham', text    [i, am, at, a, party, with, alex, nichols]
# Name: 571, dtype: object, 'Ham', text    [are, norm, tomorrow, i, finish, 415, cos, st,...
# Name: 572, dtype: object, 'Ham', text    [are, free, nowcan, call]
# Name: 573, dtype: object, 'Spam', text    [okey, dokey, swashbuckling, stuff, oh]
# Name: 574, dtype: object, 'Ham', text    [but, shes, drinkin, i'm, ok]
# Name: 575, dtype: object, 'Ham', text    [do, ì_, wan, 2, meet, n, combine, parts, how'...
# Name: 576, dtype: object, 'Ham', text    [not, course, only, maths, one, day, one, chap...
# Name: 577, dtype: object, 'Ham', text    [&lt&gt, %of, pple, marry, lovers, becz, hav, ...
# Name: 578, dtype: object, 'Ham', text    [when, guys, planning, coming]
# ...
# Name: 921, dtype: object, 'Ham', text    [we, stopped, get, ice, cream, go, back]
# Name: 922, dtype: object, 'Ham', text    [double, mins, &, double, txt, &, 12, price, l...
# Name: 923, dtype: object, 'Spam', text    [wish, u, many, many, returns, day, happy, bir...
# Name: 924, dtype: object, 'Ham', text    [you, also, didnt, get, na, hi, hi, hi, hi, hi]
# Name: 925, dtype: object, 'Ham', text    [gr8, so, handle, victoria, island, traffic, p...
# Name: 926, dtype: object, 'Ham', text    [ok, careful, , don't, text, drive, ]
# Name: 927, dtype: object, 'Ham', text    [y, dun, believe, leh, i, tot, told, true, alr...
# Name: 928, dtype: object, 'Ham', text    [free, entry, 2, weekly, comp, chance, win, ip...
# Name: 929, dtype: object, 'Spam', text    [dearshall, mail, tonitebusy, streetshall, upd...
# Name: 930, dtype: object, 'Ham', text    [midnight, earliest]
# Name: 931, dtype: object, 'Ham', text    [, ow, u, deyi, paid, 60400thousadi, told, , u...
# Name: 932, dtype: object, 'Ham', text    [life, alle, moneeppolum, oru, pole, allalo]
# Name: 933, dtype: object, 'Ham', text    [webpage, available]
# Name: 934, dtype: object, 'Ham', text    [congrats, 2, mobile, 3g, videophones, r, call...
# Name: 935, dtype: object, 'Ham', text    [urgent, your, 4, costa, del, sol, holiday, å5...
# Name: 936, dtype: object, 'Spam', text    [all, come, alivebetter, correct, good, lookin...
# Name: 937, dtype: object, 'Ham', text    [uhhhhrmm, isnt, tb, test, bad, youre, sick]
# Name: 938, dtype: object, 'Ham', text    [bugis, oso, near, wat, ]
# Name: 939, dtype: object, 'Ham', text    [dont, search, love, let, love, find, u, thats...
# Name: 940, dtype: object, 'Ham', text    [u, win, å100, music, gift, vouchers, every, w...
# Name: 941, dtype: object, 'Ham', text    [why, tired, special]
# Name: 942, dtype: object, 'Ham', text    [trust, even]
# Name: 943, dtype: object, 'Ham', text    [i, love, ass, do, enjoy, doggy, style, :)]
# Name: 944, dtype: object, 'Ham', text    [somebody, set, website, play, hold, em, using...
# Name: 945, dtype: object, 'Ham', text    [the, fact, cleaning, shows, know, i'm, upset,...
# Name: 946, dtype: object, 'Ham', text    [usually, person, unconscious, that's, childre...
# Name: 947, dtype: object, 'Ham', text    [oh, come, ah]
# Name: 948, dtype: object, 'Ham', text    [i, want, lick, pussy]
# Name: 949, dtype: object, 'Ham', text    [splashmobile:, choose, 1000s, gr8, tones, wk,...
# Name: 950, dtype: object, 'Ham', text    [<forwarded, 448712404000>please, call, 087124...
# Name: 951, dtype: object, 'Spam', text    [i, want, leave, but, i'm, barely, stay, sane,...
# Name: 952, dtype: object, 'Ham', text    [r, still, meeting, 4, dinner, tonight]
# Name: 953, dtype: object, 'Ham', text    [think, ur, smart, , win, å200, week, weekly, ...
# Name: 954, dtype: object, 'Ham', text    [what, type, stuff, sing]
# Name: 955, dtype: object, 'Ham', text    [actually, deleted, old, websitenow, blogging,...
# Name: 956, dtype: object, 'Ham', text    [prepare, pleasured, :)]
# Name: 957, dtype: object, 'Ham', text    [the, world, running, stillmaybe, feeling, sam...
# Name: 958, dtype: object, 'Ham', text    [ok, ill, tell, company]
# Name: 959, dtype: object, 'Ham', text    [i, want, sent, , &lt&gt, mesages, today, that...
# Name: 960, dtype: object, 'Ham', text    [i, thk, ì_, gotta, go, home, urself, cos, i'l...
# Name: 961, dtype: object, 'Ham', text    [you, important, customer, service, announceme...
# Name: 962, dtype: object, 'Spam', text    [wot, u, 2, bitch]
# Name: 963, dtype: object, 'Ham', text    [i, accidentally, brought, em, home, box]
# Name: 964, dtype: object, 'Ham', text    [haha, friend, tyler, literally, asked, could,...
# Name: 965, dtype: object, 'Ham', text    [when, u, wana, see]
# Name: 966, dtype: object, 'Ham', text    [babe, , i, lost, , :(]
# Name: 967, dtype: object, 'Ham', text    [india, take, lead:)]
# Name: 968, dtype: object, 'Ham', text    [sorry, i, can't, help]
# Name: 969, dtype: object, 'Ham', text    [it, took, mr, owl, 3, licks]
# Name: 970, dtype: object, 'Ham', text    [ok, going, sleep, hope, meet]
# Name: 971, dtype: object, 'Ham', text    [wait, , i, msg, , &lt&gt, , min]
# Name: 972, dtype: object, 'Ham', text    [i, liked, new, house]
# Name: 973, dtype: object, 'Ham', text    [lol, , have, made, plans, new, years]
# Name: 974, dtype: object, 'Ham', text    [they, put, stuff, roads, keep, getting, slipp...
# Name: 975, dtype: object, 'Ham', text    [what, said, matter, my, mind, saying, matter]
# Name: 976, dtype: object, 'Ham', text    [ok, but, said, i've, got, wisdom, teeth, hidd...
# Name: 977, dtype: object, 'Ham', text    [congratulations, thanks, good, friend, u, won...
# Name: 978, dtype: object, 'Ham', text    [will, food]
# Name: 979, dtype: object, 'Ham', text    [the, current, leading, bid, 151, to, pause, a...
# Name: 980, dtype: object, 'Spam', text    [good, words, but, words, may, leave, u, disma...
# Name: 981, dtype: object, 'Ham', text    [can, u, get, pic, msgs, phone]
# Name: 982, dtype: object, 'Ham', text    [me, have, lovely, night, xxx]
# Name: 983, dtype: object, 'Ham', text    [is, toshiba, portege, m100, gd]
# Name: 984, dtype: object, 'Ham', text    [moon, come, color, dreams, stars, make, music...
# Name: 985, dtype: object, 'Ham', text    [no, plans, yet, what, ]
# Name: 986, dtype: object, 'Ham', text    [i'm, da, bus, going, home]
# Name: 987, dtype: object, 'Ham', text    [you, flippin, shit, yet]
# Name: 988, dtype: object, 'Ham', text    [have, emigrated, something, ok, maybe, 530, b...
# Name: 989, dtype: object, 'Ham', text    [or, u, ask, next, sat, if, make, i'm, ok, lor]
# Name: 990, dtype: object, 'Ham', text    [already, squatting, new, way, walking]
# Name: 991, dtype: object, 'Ham', text    [probably, money, worries, things, coming, due...
# Name: 992, dtype: object, 'Ham', text    [hen, night, going, swing]
# Name: 993, dtype: object, 'Ham', text    [u're, welcome, caught, u, using, broken, engl...
# Name: 994, dtype: object, 'Ham', text    [iû÷ll, look, frying, pan, case, itû÷s, chea...
# Name: 995, dtype: object, 'Ham', text    [free, video, camera, phones, half, price, lin...
# Name: 996, dtype: object, 'Spam', text    [well, im, computerless, time, make, oreo, tru...
# Name: 997, dtype: object, 'Ham', text    [sorry, i, can't, help]
# Name: 998, dtype: object, 'Ham', text    [free, 1st, week, no1, nokia, tone, 4, ur, mob...
# Name: 999, dtype: object, 'Spam', text    [tell, make, little, spreadsheet, track, whose...
# Name: 1000, dtype: object, 'Ham', text    [\are, comingdown, later\""]
# Name: 1001, dtype: object, 'I dont know', text    [you, mu, you, try, figure, much, money, every...
# Name: 1002, dtype: object, 'Ham', text    [y, ì_, wan, go, c, doctor]
# Name: 1003, dtype: object, 'Ham', text    [went, ganesh, dress, shop]
# Name: 1004, dtype: object, 'Ham', text    [hmmmstill, dont, opener]
# Name: 1005, dtype: object, 'Ham', text    [i, late, i]
# Name: 1006, dtype: object, 'Ham', text    [so, u, today]
# Name: 1007, dtype: object, 'Ham', text    [macha, dont, feel, upseti, assume, mindsetbel...
# Name: 1008, dtype: object, 'Ham', text    [a, å400, xmas, reward, is, waiting, for, you,...
# Name: 1009, dtype: object, 'Ham', text    [kk:)how, much, cost]
# Name: 1010, dtype: object, 'Ham', text    [ìï, comin, fetch, us, oredi]
# Name: 1011, dtype: object, 'Ham', text    [urgent, your, mobile, no, , won, å2000, bonus...
# Name: 1012, dtype: object, 'Ham', text    [yup, shd, haf, ard, 10, pages, add, figures, ...
# Name: 1013, dtype: object, 'Ham', text    [where, lover, , i, need, ]
# Name: 1014, dtype: object, 'Ham', text    [bring, home, wendy, =d]
# Name: 1015, dtype: object, 'Ham', text    [hey, morning, come, ask:), pa]
# Name: 1016, dtype: object, 'Ham', text    [happy, new, years, melody]
# Name: 1017, dtype: object, 'Ham', text    [free, ring, tone, text, \polys\", 87131, then...
# Name: 1018, dtype: object, 'I dont know', text    [k, i, might, come, tonight, class, lets, early]
# Name: 1019, dtype: object, 'Ham', text    [\pete, please, ring, meive, hardly, gotany, c...
# Name: 1020, dtype: object, 'Ham', text    [then, ur, physics, get]
# Name: 1021, dtype: object, 'Ham', text    [mobile, number, å5000, claim, calls, us, back...
# Name: 1022, dtype: object, 'Spam', text    [is, ur, changes, 2, da, report, big, cos, i'v...
# Name: 1023, dtype: object, 'Ham', text    [funny, fact, nobody, teaches, volcanoes, 2, e...
# Name: 1024, dtype: object, 'Ham', text    [no, cancelled, yeah, baby, well, sounds, impo...
# Name: 1025, dtype: object, 'Ham', text    [dip's, cell, dead, so, coming, u, better, res...
# Name: 1026, dtype: object, 'Ham', text    [i, think, chennai, well, settled]
# Name: 1027, dtype: object, 'Ham', text    [good, afternon, love, how, today, i, hope, go...
# Name: 1028, dtype: object, 'Ham', text    [was, gr8, see, message, so, r, u, leaving, co...
# Name: 1029, dtype: object, 'Ham', text    [what, i'm, saying, explicitly, told, nora, i,...
# Name: 1030, dtype: object, 'Ham', text    [are, much, buzy]
# Name: 1031, dtype: object, 'Ham', text    [yep, get, program, you're, slacking]
# Name: 1032, dtype: object, 'Ham', text    [i, see, half, hour]
# Name: 1033, dtype: object, 'Ham', text    [rose, redred, bloodblood, heartheart, u, but,...
# Name: 1034, dtype: object, 'Ham', text    [may, call, you, later, pls]
# Name: 1035, dtype: object, 'Ham', text    [call, 09095350301, send, girls, erotic, ecsta...
# Name: 1036, dtype: object, 'Spam', text    [bloomberg, message, center, 447797706009, why...
# Name: 1037, dtype: object, 'Ham', text    [xmas, iscoming, &, ur, awarded, either, å500,...
# Name: 1038, dtype: object, 'Ham', text    [pls, come, quick, cant, bare]
# Name: 1039, dtype: object, 'Ham', text    [talk, sexy, make, new, friends, fall, love, w...
# Name: 1040, dtype: object, 'Ham', text    [night, ended, another, day, morning, come, sp...
# Name: 1041, dtype: object, 'Ham', text    [lol, , grins, , i'm, babe, thanks, thinking]
# Name: 1042, dtype: object, 'Ham', text    [dude, what's, how, teresa, hope, okay, when, ...
# Name: 1043, dtype: object, 'Ham', text    [pandy, joined, 4w, technologies, todayhe, got...
# Name: 1044, dtype: object, 'Ham', text    [hello, peach, my, cake, tasts, lush]
# Name: 1045, dtype: object, 'Ham', text    [merry, christmas, babe, love, ya, kisses]
# Name: 1046, dtype: object, 'Ham', text    [well, i, leave, class, babe, , you, never, ca...
# Name: 1047, dtype: object, 'Ham', text    [congratulations, ur, awarded, 500, cd, vouche...
# Name: 1048, dtype: object, 'Spam', text    [ur, ringtone, service, changed, 25, free, cre...
# Name: 1049, dtype: object, 'Spam', text    [u, need, presnts, always, bcz, u, cant, mis, ...
# Name: 1050, dtype: object, 'Ham', text    [are, driving, training]
# Name: 1051, dtype: object, 'Ham', text    [kinda, first, one, gets, twelve, aah, speak, ...
# Name: 1052, dtype: object, 'Ham', text    [rajipls, favour, pls, convey, birthday, wishe...
# Name: 1053, dtype: object, 'Ham', text    [all, day, working, day:)except, saturday, sun...
# Name: 1054, dtype: object, 'Ham', text    [aight, i'll, grab, something, eat, text, back...
# Name: 1055, dtype: object, 'Ham', text    [k, did, call, ah, ]
# Name: 1056, dtype: object, 'Ham', text    [so, asked, how's, anthony, dad, and, bf]
# Name: 1057, dtype: object, 'Ham', text    [how, dare, stupid, i, wont, tell, anything, h...
# Name: 1058, dtype: object, 'Ham', text    [its, time, month, mid, time]
# Name: 1059, dtype: object, 'Ham', text    [i, but, tell, quite, long, cos, finish, film,...
# Name: 1060, dtype: object, 'Ham', text    [urgent, we, trying, contact, u, todays, draw,...
# Name: 1061, dtype: object, 'Ham', text    [moji, informed, saved, lives, thanks]
# Name: 1062, dtype: object, 'Ham', text    [sure, thing, big, man, hockey, elections, 6, ...
# Name: 1063, dtype: object, 'Ham', text    [sorry, sent, blank, msg, yup, trying, 2, seri...
# Name: 1064, dtype: object, 'Ham', text    [oh, k, k:)but, big, hitteranyway, good]
# Name: 1065, dtype: object, 'Ham', text    [thats, bit, weird, even, , supposed, happenin...
# Name: 1066, dtype: object, 'Ham', text    [its, like, hotel, dusk, game, think, you, sol...
# Name: 1067, dtype: object, 'Ham', text    [this, message, brought, gmw, ltd, connected]
# Name: 1068, dtype: object, 'Ham', text    [housemaid, murderer, coz, man, murdered, , &l...
# Name: 1069, dtype: object, 'Ham', text    [wat, r, u]
# Name: 1070, dtype: object, 'Ham', text    [can, plz, tell, ans, bslvyl, sent, via, fullo...
# Name: 1071, dtype: object, 'Ham', text    [you, contacted, dating, service, someone, kno...
# Name: 1072, dtype: object, 'Ham', text    [probably, want, pick]
# Name: 1073, dtype: object, 'Ham', text    [dunno, u, ask]
# Name: 1074, dtype: object, 'Ham', text    [it, issues, right, ill, fix, tomorrow]
# Name: 1075, dtype: object, 'Ham', text    [then, responding]
# Name: 1076, dtype: object, 'Ham', text    [good, afternoon, glorious, anniversary, day, ...
# Name: 1077, dtype: object, 'Ham', text    [sweet, well, princess, please, tell, likes, d...
# Name: 1078, dtype: object, 'Ham', text    [s, took, tablets, , reaction, morning]
# Name: 1079, dtype: object, 'Ham', text    [did, say, bold, torch, later, or, one, torch,...
# Name: 1080, dtype: object, 'Ham', text    [my, parents, my, kidz, my, friends, n, my, co...
# Name: 1081, dtype: object, 'Ham', text    [i, wont, anything, de]
# Name: 1082, dtype: object, 'Ham', text    [filthy, stories, girls, waiting]
# Name: 1083, dtype: object, 'Ham', text    [science, tells, chocolate, melt, sunlight, pl...
# Name: 1084, dtype: object, 'Ham', text    [just, sent, so, type, food, like]
# Name: 1085, dtype: object, 'Ham', text    [give, one, miss, number, please]
# Name: 1086, dtype: object, 'Ham', text    [babe, i'm, answering, can't, see, , maybe, be...
# Name: 1087, dtype: object, 'Ham', text    [at, home, way]
# Name: 1088, dtype: object, 'Ham', text    [that, means, get, door]
# Name: 1089, dtype: object, 'Ham', text    [i, can't, right, second, gotta, hit, people, ...
# Name: 1090, dtype: object, 'Ham', text    [hostbased, idps, linux, systems]
# Name: 1091, dtype: object, 'I dont know', text    [auction, round, 4, the, highest, bid, å54, ne...
# Name: 1092, dtype: object, 'Ham', text    [no, one, interested, may, business, plan]
# Name: 1093, dtype: object, 'Ham', text    [my, trip, ok, quite, tiring, lor, uni, starts...
# Name: 1094, dtype: object, 'Ham', text    [ok, , , bus, , if, come, soon, come, otherwis...
# Name: 1095, dtype: object, 'Ham', text    [final, chance, claim, ur, å150, worth, discou...
# Name: 1096, dtype: object, 'Spam', text    [, &lt&gt, , mins, stop, somewhere, first]
# Name: 1097, dtype: object, 'Ham', text    [dunno, lei, i, might, b, eatin, wif, frens, i...
# Name: 1098, dtype: object, 'Ham', text    [get, garden, ready, summer, free, selection, ...
# Name: 1099, dtype: object, 'Spam', text    [tells, u, 2, call, 09066358152, claim, å5000,...
# Name: 1100, dtype: object, 'Ham', text    [sad, story, man, , last, week, b'day, my, wif...
# Name: 1101, dtype: object, 'Ham', text    [so, didnt, holla]
# Name: 1102, dtype: object, 'Ham', text    [freemsg:, 1month, unlimited, free, calls, act...
# Name: 1103, dtype: object, 'Spam', text    [i'm, home]
# Name: 1104, dtype: object, 'Ham', text    [well, there's, lot, things, happening, lindsa...
# Name: 1105, dtype: object, 'Ham', text    [ok, ìï, finishing, soon]
# Name: 1106, dtype: object, 'Ham', text    [win:, we, winner, mr, t, foley, ipod, more, e...
# Name: 1107, dtype: object, 'Ham', text    [this, creepy, crazy]
# Name: 1108, dtype: object, 'Ham', text    [have, bookedthe, hut, and, also, time, how, way]
# Name: 1109, dtype: object, 'Ham', text    [yo, chad, gymnastics, class, wanna, take, the...
# Name: 1110, dtype: object, 'Ham', text    [god, created, gap, btwn, ur, fingers, dat, su...
# Name: 1111, dtype: object, 'Ham', text    [i'm, working, technical, support, :)voice, pr...
# Name: 1112, dtype: object, 'Ham', text    [i, told, number, gautham]
# Name: 1113, dtype: object, 'Ham', text    [well, big, surprise]
# Name: 1114, dtype: object, 'Ham', text    [u]
# Name: 1115, dtype: object, 'Ham']

# %% [markdown]
# ## Step 6:- Cheat the classifier[20 points]
#
# #### Try to cheat the classifier by adding "good words" to the end of test dataset(TestDataset.csv) e.g:- Oh! no share Market has fallen down by $100,000 due to Corona outbreak... try mixing up spam and ham words see how the classifier works. Output the results in a good format to validate your work[15 points]

# %%
brut = loadData('TestDataset.csv')

net_new = preProcessing(brut)
vec = []

print('When the filter is not able to recognize spam or ham, the next message will appear: I need human help')
for i, row in net_new.iterrows():
    vec.append(row)
    vec.append(classify(row['text'], ham_vec, spam_vec))
# Out:
# When the filter is not able to recognize spam or ham, the next message will appear: I need human help
# ['erutupalam', 'thandiyachu']  I need human help
# ['gwr']  I need human help
# ['staffsciencenusedusg~phyhcmkteachingpc1323']  I need human help
# ['645']  I need human help
# ['kk:)where', 'youhow', 'performed']  I need human help
# ['\\are', 'comingdown', 'later\\""']  I need human help
# ['free', 'ring', 'tone', 'text', '\\polys\\"', '87131', 'then', 'every', 'week', 'get', 'new', 'tone', '0870737910216yrs', 'å150wk"']  I need human help
# ['hostbased', 'idps', 'linux', 'systems']  I need human help

# %% [markdown]
# #### Write your analysis of how you intended to cheat the classifier and how it performed in few words (provide your inference)[5 points]

# %% [markdown]
# When the probability of the message is the same for Spam and Ham, the classifier doesn't know what to do:
#
# - Every word in the message has a probability to belong to a Ham or Spam (p_s and p_h)
# - To cheat the classifier, the total probability of the words are iqual p_s = p_h
# - To reach a balance the quantity of ham words and spam words would be almost the same
# - In that case the classifier needs human help

# %% [markdown]
# ### Help
#
# <a href="https://en.wikipedia.org/wiki/Naive_Bayes_spam_filtering" target="_top">Spam Filtering using Naive Bayes</a><br>
# <a href="https://seaborn.pydata.org/generated/seaborn.heatmap.html" target="_top">Seaborn Heatmap</a><br>
# <a href="https://scikit-learn.org/stable/modules/naive_bayes.html" target="_top">Sklearn Naive Bayes</a><br>
# <a href="https://scikit-learn.org/stable/modules/model_evaluation.html" target="_top">Sklearn Metrics</a><br>
# <a href="https://pandas.pydata.org/docs/getting_started/index.html#getting-started" target="_top">Intro to Pandas</a>
